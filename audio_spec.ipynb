# %%
import librosa

# %%
import os
os.getcwd()
# Out:
# '/Users/jiwonpark/Desktop/workspace'

# %%
audio_data = '/Users/jiwonpark/Downloads/docs_feature_extraction_example.wav'

# %%
x, sr = librosa.load(audio_data)
print(type(x), type(sr))
# Out:
# <class 'numpy.ndarray'> <class 'int'>

# %%
librosa.load(audio_data, sr=44100) #resampling at 44.1kHz
# Out:
# (array([0.00104241, 0.00119511, 0.00120082, ..., 0.00021918, 0.00012567,
#         0.        ], dtype=float32),
#  44100)

# %%
import IPython.display as ipd
ipd.Audio(audio_data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(16, 6))
librosa.display.waveshow(x, sr=sr)
plt.show()

# %%
#spectogram
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(16,8))
plt.subplot(2,1,1)
librosa.display.specshow(Xdb, sr=sr, x_axis = 'time', y_axis='hz')
plt.colorbar()
plt.title('hz')
plt.show()

plt.figure(figsize=(16,8))
plt.subplot(2,1,2)
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()
plt.show()
